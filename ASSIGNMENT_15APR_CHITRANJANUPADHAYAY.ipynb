# %%
# Answer1.

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# Assuming you have already loaded your dataset into X (features) and y (target)

# Define the columns based on their data types
numerical_columns = [...]  # List of numerical column names
categorical_columns = [...]  # List of categorical column names

# Create transformers for numerical and categorical features
numerical_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # Handle missing values by imputing with mean
    ('scaler', StandardScaler())  # Scale the numerical features
])

categorical_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),  # Handle missing values by imputing with most frequent value
    ('encoder', OneHotEncoder())  # One-hot encode the categorical features
])

# Combine the transformers using ColumnTransformer
preprocessor = ColumnTransformer([
    ('numerical', numerical_transformer, numerical_columns),
    ('categorical', categorical_transformer, categorical_columns)
])

# Create the final pipeline by combining the preprocessor with your desired model
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', YourModelHere())  # Replace YourModelHere with the desired model class
])

# Split the data into training and test sets (assuming you have X_train, X_test, y_train, y_test)
# Then fit the pipeline on the training data and make predictions on the test data
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

# %%
# Answer2.

from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# Load the Iris dataset
iris = load_iris()
X, y = iris.data, iris.target

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create the individual classifiers
rf_classifier = RandomForestClassifier(random_state=42)
lr_classifier = LogisticRegression(random_state=42)

# Create the pipeline
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Scale the features
    ('voting_classifier', VotingClassifier([
        ('rf', rf_classifier),
        ('lr', lr_classifier)
    ]))
])

# Train the pipeline
pipeline.fit(X_train, y_train)

# Make predictions on the test set
y_pred = pipeline.predict(X_test)

# Evaluate the accuracy of the pipeline
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
